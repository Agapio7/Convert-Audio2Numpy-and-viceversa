# %% [markdown]
#  # Project: Convert audio file into Numpyarray ,array into audio and input audio from users

# %% [markdown]
# The  objectives of our project are
#
#
# * convert Audio file into numpy array,Numpy array into audio and
#
# * input audio from users using python libraries
#
#
# # Roadmap
#
#
# __Audio2Array2Audio__
#
#
# * Ipython
# * Scipy and soundfile
# * Soundfile
# * audio2numpy and soundfile
# * Soundevice
#
#
#
# __Input audio from users__
#
# * Scipy
# * Winsound
# * Pyglet
# * Pygame
# * Simple audio
# * Soundcard and soundevice
# * VLC
# * Libwinmedia
# * Audioplayer
# * gTTS
# * psychopy
# * Pydub
# * Pyaudio

# %%
import sys
sys.path
# Out:
# ['C:\\Users\\Hem\\virtaul envv',
#  'c:\\users\\hem\\.conda\\envs\\py35\\python38.zip',
#  'c:\\users\\hem\\.conda\\envs\\py35\\DLLs',
#  'c:\\users\\hem\\.conda\\envs\\py35\\lib',
#  'c:\\users\\hem\\.conda\\envs\\py35',
#  '',
#  'C:\\Users\\Hem\\AppData\\Roaming\\Python\\Python38\\site-packages',
#  'c:\\users\\hem\\.conda\\envs\\py35\\lib\\site-packages',
#  'c:\\users\\hem\\.conda\\envs\\py35\\lib\\site-packages\\win32',
#  'c:\\users\\hem\\.conda\\envs\\py35\\lib\\site-packages\\win32\\lib',
#  'c:\\users\\hem\\.conda\\envs\\py35\\lib\\site-packages\\Pythonwin',
#  'c:\\users\\hem\\.conda\\envs\\py35\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Hem\\.ipython']

# %% [markdown]
# # Ipython

# %% [markdown]
# This project is about Audio2Numpy conversion. The main objective of this project is to convert audio audio wav file into Numpy Array and viceversa. This project completes into three steps:
#
# Step 1: Import Necessaries libraries
#
# Step 2: Data Visualization
#
# Step 3 : Convert Array into Numpy
#
# Step 4: Convert Numpy into Audio

# %% [markdown]
# **Step 1:Import Necessaries libraries**
#
# We are using various python libraries to achieve our objectives. We are using various python libraries.We will first install various libraires such as librsa,matlplotlib,Ipython and soundfile.

# %%
# !pip install librosa

# %%
import matplotlib.pyplot as plt   
# %matplotlib inline
import IPython.display as ipd
import librosa
import librosa.display

# %% [markdown]
# **Step 2:Data Visualization**
#
# In this step we uploaded our audio file on colab. We then give file location path. We used matlplotlib to visualize our auido into wave in figure.Aftet that we used librosa and ipython to display voice

# %%
filename='realvoice.wav'


plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveplot(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
X = librosa.stft(data)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize=(14, 5))
librosa.display.specshow(Xdb, sr=sample_rate, x_axis='time', y_axis='hz')
plt.colorbar()

# %% [markdown]
# **Step 3: Convert audio into Array**

# %%
print(sample_rate)
# Out:
# 22050

# %%
print(data)
# Out:
# [0.00654906 0.00988176 0.00868438 ... 0.00982417 0.00904579 0.00980019]

# %%
print(data.dtype)
# Out:
# float32

# %% [markdown]
# **Step 4: Convert Numpy Array in AUDIO**
#
# Lastly, we again converted Array into original audio using soundfile library.

# %%
import numpy as np           #ConvertNumpy2audio
import soundfile as sf     # or import sounddevice as sd


sf.write('soundi.wav', data, sample_rate)

# %% [markdown]
# # Other methods to convert audio into array and array into numpy

# %% [markdown]
# **1.Scipy(Integar)**

# %%
from scipy.io import wavfile
fs, data = wavfile.read('realvoice.wav')

# %%
fs, data
# Out:
# (48000, array([299, 299, 299, ..., 304, 306, 297], dtype=int16))

# %%
# !pip install soundfile

# %%
import numpy as np           #ConvertNumpy2audio
import soundfile as sf     # or import sounddevice as sd


sf.write('dd.wav', data, fs)

# %% [markdown]
# **2.soundfile(floating)**

# %%
import soundfile as sf
data, samplerate = sf.read('realvoice.wav')
data,samplerate
# Out:
# (array([0.00912476, 0.00912476, 0.00912476, ..., 0.00927734, 0.00933838,
#         0.00906372]),
#  48000)

# %%
print(data.dtype)
# Out:
# float64

# %%
import numpy as np           
import soundfile as sf     


sf.write('m.wav', data, fs)

# %% [markdown]
# **3.AUDIO2NUMPY(floating)**

# %%
pip install audio2numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !apt install ffmpeg
# Out:
# 'apt' is not recognized as an internal or external command,
# operable program or batch file.

# %%
from audio2numpy import open_audio
fp = "realvoice.wav"  # change to the correct path to your file accordingly
signal, sampling_rate = open_audio(fp)

# %%
sampling_rate
# Out:
# 48000

# %%
signal
# Out:
# array([0.00912476, 0.00912476, 0.00912476, ..., 0.00927734, 0.00933838,
#        0.00906372], dtype=float32)

# %%
import numpy as np           
import soundfile as sf     


sf.write('output1.wav', signal, sampling_rate)

# %% [markdown]
# **4.Sounddevice(Integer)**

# %%
from scipy.io import wavfile
fs , data = wavfile.read('realvoice.wav')

# %%
data
# Out:
# array([299, 299, 299, ..., 304, 306, 297], dtype=int16)

# %%
fs
# Out:
# 48000

# %%
import numpy as np
import sounddevice as sd



sd.play(data, fs)

# %% [markdown]
# # Record audio using python

# %% [markdown]
# ## SCIPY

# %%
import sounddevice as sd
import numpy as np
import scipy.io.wavfile as wav

fs=44100
duration = 15  # seconds
myrecording = sd.rec(duration * fs, samplerate=fs, channels=2,dtype='float64')
print ("Recording Audio")
sd.wait()
print ("Audio recording complete , Play Audio")
sd.play(myrecording, fs)
sd.wait()
print("Play Audio Complete")
# Out:
# Recording Audio
# Audio recording complete , Play Audio
# Play Audio Complete

# %%
import wavio

wavio.write("hloo.wav", myrecording, fs, sampwidth=2)

# %% [markdown]
# # Winsound

# %%
pip install winsound
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement winsound
# ERROR: No matching distribution found for winsound

# %%
import winsound

winsound.PlaySound('nepali.wav', winsound.SND_FILENAME)

# %%
import winsound

winsound.PlaySound('SystemHand', winsound.SND_ALIAS)

winsound.PlaySound('xx', winsound.SND_ALIAS)

winsound.PlaySound('nepali.wav', winsound.SND_FILENAME)

# %% [markdown]
# # pyglet

# %%
pip install pyglet
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pyglet

music = pyglet.resource.media('realvoice.wav')
music.play()

pyglet.app.run()

# %% [markdown]
# # Pygame

# %%
pip install -U pygame --user

# %%
import pygame
# Out:
# pygame 2.0.2 (SDL 2.0.16, Python 3.8.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
pygame.mixer.init()
pygame.mixer.music.load("realvoice.wav")
pygame.mixer.music.play()

# %% [markdown]
# # Simple audio

# %%
pip install simpleaudio
# Out:
# ...
#   Using cached simpleaudio-1.0.4-cp38-cp38-win_amd64.whl (2.0 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import simpleaudio as sa

wave_obj = sa.WaveObject.from_wave_file("realvoice.wav")
play_obj = wave_obj.play()
play_obj.wait_done()

# %% [markdown]
# # Soundcard and sounddevice

# %%
pip install sounddevice --user
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install SoundCard
# Out:
# ...
#   Using cached SoundCard-0.4.1-py3-none-any.whl (40 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import soundfile as sf
import soundcard as sc

default_speaker = sc.default_speaker()
samples, samplerate = sf.read('realvoice.wav')

default_speaker.play(samples, samplerate=samplerate)

# %% [markdown]
# # VLC

# %%
pip install python-vlc
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import  vlc
audio_file = vlc.MediaPlayer("realvoice.wav")
audio_file.play()
# Out:
# 0

# %%
audio_file.stop()

# %% [markdown]
# #  Libwinmedia

# %%
pip install libwinmedia

# %%
import libwinmedia

player = libwinmedia.Player(True)

player.set_position_callback(lambda position: print(f"{position} ms."))
media = libwinmedia.Media("realvoice.wav")

player.open(media)
# Out:
# 0 ms.

# %% [markdown]
# #  Audioplayer

# %%
pip install audioplayer
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from audioplayer import AudioPlayer
AudioPlayer("realvoice.wav").play(block=True)

# %% [markdown]
# # gTTS

# %%
pip install gTTS
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS
tts = gTTS('Nepal is a beautiful country')
tts.save('copy.wav')

# %% [markdown]
# # Psychopy

# %%
pip install psychopy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...

# %%
import psychtoolbox as ptb
from psychopy import sound

mySound = sound.Sound('realvoice.wav')
now = ptb.GetSecs()
mySound.play(when=now+0.5)  # play in EXACTLY 0.5s

# %% [markdown]
# # Pydub

# %%
from pydub import AudioSegment
from pydub.playback import play

fname = "realvoice.wav"
mysong = AudioSegment.from_wav(fname)
play(mysong)

# %% [markdown]
# # pyaudio

# %%
import pyaudio
import wave

chunk = 1024  # Record in chunks of 1024 samples
sample_format = pyaudio.paInt16  # 16 bits per sample
channels = 2
fs = 44100  # Record at 44100 samples per second
seconds = 20
filename = "ZZZV.wav"

p = pyaudio.PyAudio()  # Create an interface to PortAudio

print('Recording')

stream = p.open(format=sample_format,
                channels=channels,
                rate=fs,
                frames_per_buffer=chunk,
                input=True)

frames = []  # Initialize array to store frames

# Store data in chunks for 20 seconds
for i in range(0, int(fs / chunk * seconds)):
    data = stream.read(chunk)
    frames.append(data)

# Stop and close the stream 
stream.stop_stream()
stream.close()
# Terminate the PortAudio interface
p.terminate()

print('Finished recording')
# Out:
# Recording
# Finished recording

# %%
# Save the recorded data as a WAV file
wf = wave.open(filename, 'wb')
wf.setnchannels(channels)
wf.setsampwidth(p.get_sample_size(sample_format))
wf.setframerate(fs)
wf.writeframes(b''.join(frames))
wf.close()

# %%
import pyaudio
import wave

CHUNK = 1024
FORMAT = pyaudio.paInt16
CHANNELS = 2
RATE = 44100
RECORD_SECONDS = 5
WAVE_OUTPUT_FILENAME = "output.wav"

p = pyaudio.PyAudio()

stream = p.open(format=FORMAT,
                channels=CHANNELS,
                rate=RATE,
                input=True,
                frames_per_buffer=CHUNK)

print("* recording")

frames = []

for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
    data = stream.read(CHUNK)
    frames.append(data)

print("* finish recording")

stream.stop_stream()
stream.close()
p.terminate()

wf = wave.open(WAVE_OUTPUT_FILENAME, 'wb')
wf.setnchannels(CHANNELS)
wf.setsampwidth(p.get_sample_size(FORMAT))
wf.setframerate(RATE)
wf.writeframes(b''.join(frames))
wf.close()
# Out:
# * recording
# * finish recording

# %% [markdown]
# # Reference
#
#
# https://pypi.org/project/audio2numpy/
#
# https://stackoverflow.com/questions/53633177/how-to-read-a-mp3-audio-file-into-a-numpy-array-save-a-numpy-array-to-mp3
#
# https://stackoverflow.com/questions/10357992/how-to-generate-audio-from-a-numpy-array/37423879
#
# https://www.py4u.net/discuss/13502
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.io.wavfile.write.html
#
# https://coderedirect.com/questions/254162/how-to-read-a-mp3-audio-file-into-a-numpy-array-save-a-numpy-array-to-mp3
#
# https://docs.conda.io/projects/conda/en/4.6.0/_downloads/52a95608c49671267e40c689e0bc00ca/conda-cheatsheet.pdf
#
# https://librosa.org/doc/latest/index.html
#
# https://numpy.org/install/
#
# https://pypi.org/project/SoundFile/
#
# https://pypi.org/project/sounddevice/
#
# https://pypi.org/project/PyAudio/
#
# https://matplotlib.org/
#
# https://pypi.org/project/matplotlib/
#
# https://www.psychopy.org/download.html
#
# https://www.youtube.com/watch?v=CeFWBzzcj8o&t=16s
#
# https://stackoverflow.com/questions/53065940how-to-reinstall-a-pip-package-even-if-it-exists
#
# https://www.youtube.com/watch?v=FKwicZF7xNE
#
# https://pypi.org/project/wavio/
#
# https://pypi.org/project/librosa/
#
# https://github.com/mytja/libwinmedia-py
#
# https://stackoverflow.com/questions/52283840i-cant-install-pyaudio-on-windows-how-to-solve-error-microsoft-visual-c-14
#
# https://pythonbasics.org/python-play-sound/
#
# https://stackoverflow.com/questions/260738/play-audio-with-python
#
# https://ipython.org/ipython-doc/dev/install/index.html
#
# https://pysoundfile.readthedocs.io/en/latest/
#
# https://pypi.org/project/pyglet/
#
# https://www.pygame.org/wiki/GettingStarted
#
# https://simpleaudio.readthedocs.io/en/latest/installation.html
#
# https://python-sounddevice.readthedocs.io/en/0.4.3/installation.html
#
# https://soundcard.readthedocs.io/en/latest/
#
# https://pypi.org/project/audioplayer/
#
# https://gtts.readthedocs.io/en/latest/
#
# https://pypi.org/project/python-vlc/
#
# https://github.com/TaylorSMarks/playsound
#
# https://www.youtube.com/watch?v=mHPpCXqQd7Y
